# %%
import pandas as pd
import random
df1 = pd.read_csv("Agri.csv")

# %%
df1.drop([0])
df1.drop(['TYPE_OF_CROP'],axis=1)
# Out:
#            CROPS                                               SOIL  \
# 0            NaN                                                NaN
# 1           rice                   Alluvia or loamy and clayey soil
# 2          wheat                                       Well Drained
# 3          maize  temperate podzols to the leached red soils of ...
# 4        sorghum                           well-drained loamy soils
# ..           ...                                                ...
# 101         Mint                                         Loamy soil
# 102        Palak                                         Sandy loam
# 103      Rhubarb                                         Sandy loam
# 104       Turnip                                         Loamy soil
# 105  Winged Bean                                         Sandy loam
#
#      SOIL_PH_LOW  SOIL_PH_HIGH  CROPDURATION_MIN  CROPDURATION_MAX  MIN_TEMP  \
# 0            NaN           NaN               NaN               NaN       NaN
# 1            5.0           8.0             150.0             150.0      20.0
# 2            6.0           7.0              80.0              90.0      21.0
# 3            5.5           7.0             105.0             110.0      18.0
# 4            6.0           7.5              95.0             105.0      15.0
# ..           ...           ...               ...               ...       ...
# 101          6.5           7.0             100.0             120.0      20.0
# 102          6.5           7.0              37.0              45.0      10.0
# 103          6.0           6.8              56.0              70.0       5.0
# 104          5.5           6.8              42.0              56.0      10.0
# 105          7.0          12.0              42.0              42.0      25.0
#
#      MAX_TEMP WATERSOURCE  WATERREQUIRED_MIN  ...        Unnamed: 41  \
# 0         NaN         NaN                NaN  ...  THIRUCHIRAPALLI\n
# 1        40.0        both              900.0  ...                  1
# 2        24.0        both              450.0  ...                  0
# 3        27.0        both              500.0  ...                  1
# 4        40.0        both              450.0  ...                  1
# ..        ...         ...                ...  ...                ...
# 101      24.0        both             1000.0  ...                  1
# 102      32.0        both              900.0  ...                  1
# 103      24.0        both              900.0  ...                  1
# 104      16.0        both              900.0  ...                  1
# 105      30.0        both              900.0  ...                  1
#
#         Unnamed: 42  Unnamed: 43    Unnamed: 44        Unnamed: 45  \
# 0    THIRUNELVELI\n  THIRUPPUR\n  THIRUVALLUR\n  THIRUVANNAMALAI\n
# 1                 1            0              1                  1
# 2                 0            0              0                  1
# 3                 1            1              1                  1
# 4                 1            1              1                  1
# ..              ...          ...            ...                ...
# 101               1            1              1                  1
# 102               1            1              1                  1
# 103               1            1              1                  1
# 104               1            1              1                  1
# 105               1            1              1                  1
#
#        Unnamed: 46  Unnamed: 47 Unnamed: 48   Unnamed: 49     Unnamed: 50
# 0    THOOTHUKUDI\n  TIRUVARUR\n   VELLORE\n  VILLUPURAM\n  VIRUDHUNAGAR\n
# 1                1            1           1             1               1
# 2                0            0           1             0               0
# 3                1            1           1             1               1
# 4                1            0           1             1               1
# ..             ...          ...         ...           ...             ...
# 101              1            1           1             1               1
# 102              1            1           1             1               1
# 103              1            1           1             1               1
# 104              1            1           1             1               1
# 105              1            1           1             1               1
#
# [106 rows x 50 columns]

# %%
df1
# Out:
#            CROPS      TYPE_OF_CROP  \
# 0            NaN               NaN
# 1           rice           cereals
# 2          wheat           cereals
# 3          maize           millets
# 4        sorghum           millets
# ..           ...               ...
# 101         Mint  minor vegetables
# 102        Palak  minor vegetables
# 103      Rhubarb  minor vegetables
# 104       Turnip  minor vegetables
# 105  Winged Bean  minor vegetables
#
#                                                   SOIL  SOIL_PH_LOW  \
# 0                                                  NaN          NaN
# 1                     Alluvia or loamy and clayey soil          5.0
# 2                                         Well Drained          6.0
# 3    temperate podzols to the leached red soils of ...          5.5
# 4                             well-drained loamy soils          6.0
# ..                                                 ...          ...
# 101                                         Loamy soil          6.5
# 102                                         Sandy loam          6.5
# 103                                         Sandy loam          6.0
# 104                                         Loamy soil          5.5
# 105                                         Sandy loam          7.0
#
#      SOIL_PH_HIGH  CROPDURATION_MIN  CROPDURATION_MAX  MIN_TEMP  MAX_TEMP  \
# 0             NaN               NaN               NaN       NaN       NaN
# 1             8.0             150.0             150.0      20.0      40.0
# 2             7.0              80.0              90.0      21.0      24.0
# 3             7.0             105.0             110.0      18.0      27.0
# 4             7.5              95.0             105.0      15.0      40.0
# ..            ...               ...               ...       ...       ...
# 101           7.0             100.0             120.0      20.0      24.0
# 102           7.0              37.0              45.0      10.0      32.0
# 103           6.8              56.0              70.0       5.0      24.0
# 104           6.8              42.0              56.0      10.0      16.0
# 105          12.0              42.0              42.0      25.0      30.0
#
#     WATERSOURCE  ...        Unnamed: 41     Unnamed: 42  Unnamed: 43  \
# 0           NaN  ...  THIRUCHIRAPALLI\n  THIRUNELVELI\n  THIRUPPUR\n
# 1          both  ...                  1               1            0
# 2          both  ...                  0               0            0
# 3          both  ...                  1               1            1
# 4          both  ...                  1               1            1
# ..          ...  ...                ...             ...          ...
# 101        both  ...                  1               1            1
# 102        both  ...                  1               1            1
# 103        both  ...                  1               1            1
# 104        both  ...                  1               1            1
# 105        both  ...                  1               1            1
#
#        Unnamed: 44        Unnamed: 45    Unnamed: 46  Unnamed: 47 Unnamed: 48  \
# 0    THIRUVALLUR\n  THIRUVANNAMALAI\n  THOOTHUKUDI\n  TIRUVARUR\n   VELLORE\n
# 1                1                  1              1            1           1
# 2                0                  1              0            0           1
# 3                1                  1              1            1           1
# 4                1                  1              1            0           1
# ..             ...                ...            ...          ...         ...
# 101              1                  1              1            1           1
# 102              1                  1              1            1           1
# 103              1                  1              1            1           1
# 104              1                  1              1            1           1
# 105              1                  1              1            1           1
#
#       Unnamed: 49     Unnamed: 50
# 0    VILLUPURAM\n  VIRUDHUNAGAR\n
# 1               1               1
# 2               0               0
# 3               1               1
# 4               1               1
# ..            ...             ...
# 101             1               1
# 102             1               1
# 103             1               1
# 104             1               1
# 105             1               1
#
# [106 rows x 51 columns]

# %%
print(len(df1))
# Out:
# 106

# %%
num_entries = 30
data1 = []
for i in range(1,31):
        for _ in range(num_entries):
                crop = df1.loc[i, "CROPS"]

                soil = df1.loc[i, "SOIL"]

                water_source = df1.loc[i, "WATERSOURCE"]
                if water_source=="both":
                        water_source="irrigated,rainfall"

                soil_ph_low, soil_ph_high = df1.loc[i, "SOIL_PH_LOW"], df1.loc[i, "SOIL_PH_HIGH"]
                soil_ph = round(random.uniform(soil_ph_low, soil_ph_high), 1)

                crop_duration = random.randint(df1.loc[i, "CROPDURATION_MIN"], df1.loc[i, "CROPDURATION_MAX"])

                min_temp, max_temp = df1.loc[i, "MIN_TEMP"], df1.loc[i, "MAX_TEMP"]
                temp = round(random.uniform(min_temp, max_temp), 2)

                water_required = random.randint(df1.loc[i, "WATERREQUIRED_MIN"], df1.loc[i, "WATERREQUIRED_MAX"])

                relative_humidity_min, relative_humidity_max = df1.loc[i, "RELATIVE_HUMIDITY_MIN"], df1.loc[i, "RELATIVE_HUMIDITY_MAX"]
                relative_humidity = round(random.uniform(relative_humidity_min, relative_humidity_max), 2)

                data1.append((crop, soil, soil_ph, crop_duration, temp, water_source, water_required, relative_humidity))

# %%
df2 = pd.DataFrame(data1,columns=['CROPS','SOIL','SOIL_PH','CROP_DURATION','TEMP','WATER_SOURCE','WATER_REQUIRED','RELATIVE_HUMIDITY'])

# %%
df2
# Out:
#          CROPS                                               SOIL  SOIL_PH  \
# 0         rice                   Alluvia or loamy and clayey soil      6.8
# 1         rice                   Alluvia or loamy and clayey soil      5.8
# 2         rice                   Alluvia or loamy and clayey soil      5.0
# 3         rice                   Alluvia or loamy and clayey soil      6.4
# 4         rice                   Alluvia or loamy and clayey soil      6.8
# ..         ...                                                ...      ...
# 895  sugarcane  Clayey Loamy Soil/ Black Cotton Soil/ Red Loam...      6.5
# 896  sugarcane  Clayey Loamy Soil/ Black Cotton Soil/ Red Loam...      7.4
# 897  sugarcane  Clayey Loamy Soil/ Black Cotton Soil/ Red Loam...      7.3
# 898  sugarcane  Clayey Loamy Soil/ Black Cotton Soil/ Red Loam...      7.4
# 899  sugarcane  Clayey Loamy Soil/ Black Cotton Soil/ Red Loam...      6.8
#
#      CROP_DURATION   TEMP        WATER_SOURCE  WATER_REQUIRED  \
# 0              150  31.58  irrigated,rainfall            2307
# 1              150  23.58  irrigated,rainfall            2365
# 2              150  23.02  irrigated,rainfall            2458
# 3              150  24.76  irrigated,rainfall            1922
# 4              150  30.13  irrigated,rainfall            2226
# ..             ...    ...                 ...             ...
# 895            319  25.09           irrigated            1967
# 896            320  23.36           irrigated            2025
# 897            320  21.93           irrigated            2240
# 898            327  25.18           irrigated            1603
# 899            312  26.94           irrigated            2387
#
#      RELATIVE_HUMIDITY
# 0                76.87
# 1                70.56
# 2                79.89
# 3                63.53
# 4                78.30
# ..                 ...
# 895              65.69
# 896              76.05
# 897              66.09
# 898              69.41
# 899              77.29
#
# [900 rows x 8 columns]

# %%
df2.to_csv("rule_based_data.csv")
